# %% [markdown]
# # 1. 인구 피라미드

# %% [markdown]
# ## 남자 데이터 정의

# %%
import pandas as pd
file_name='202110_202110_연령별인구현황_월간.xlsx'
df_m = pd.read_excel(file_name, skiprows=3, index_col='행정기관', usecols='B, E:Y')
df_m.head(3)
# Out:
# C:\Users\samta\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#             0~4세       5~9세     10~14세     15~19세     20~24세     25~29세  \
# 행정기관
# 전국       795,057  1,149,123  1,215,969  1,222,407  1,637,839  1,873,533
# 서울특별시    127,719    175,290    189,528    200,015    288,842    400,438
# 부산광역시     45,722     68,049     68,311     69,025    101,216    116,280
#
#             30~34세     35~39세     40~44세     45~49세  ...     55~59세  \
# 행정기관                                                 ...
# 전국       1,664,889  1,813,973  2,030,616  2,121,949  ...  2,079,104
# 서울특별시      365,602    355,012    362,766    373,556  ...    348,150
# 부산광역시       99,888    109,024    126,297    127,308  ...    131,999
#
#             60~64세     65~69세   70~74세   75~79세   80~84세   85~89세  90~94세  \
# 행정기관
# 전국       2,043,592  1,445,830  983,284  696,342  453,472  192,704  48,788
# 서울특별시      344,954    261,250  182,751  134,277   82,383   32,570   8,683
# 부산광역시      144,693    113,836   79,759   54,377   32,542   11,904   2,783
#
#         95~99세 100세 이상
# 행정기관
# 전국       9,059   2,099
# 서울특별시    1,799     580
# 부산광역시      460     134
#
# [3 rows x 21 columns]

# %%
df_m.iloc[0] = df_m.iloc[0].str.replace(',', '').astype(int) # 1,195,951 -> 1195951
df_m
# Out:
#               0~4세     5~9세   10~14세   15~19세   20~24세   25~29세   30~34세  \
# 행정기관
# 전국          795057  1149123  1215969  1222407  1637839  1873533  1664889
# 서울특별시      127,719  175,290  189,528  200,015  288,842  400,438  365,602
# 부산광역시       45,722   68,049   68,311   69,025  101,216  116,280   99,888
# 대구광역시       34,608   52,167   55,224   59,168   80,483   85,677   73,409
# 인천광역시       46,165   66,197   70,322   69,187   92,566  111,869   99,647
# 광주광역시       23,388   35,441   38,765   40,378   54,074   54,299   43,325
# 대전광역시       22,486   33,252   35,949   37,946   51,854   58,504   49,441
# 울산광역시       19,043   28,725   29,528   28,322   37,229   40,896   36,690
# 세종특별자치시     10,167   13,788   13,011    9,755    9,144   10,423   12,951
# 경기도        233,615  332,780  344,527  335,581  439,901  511,907  464,902
# 강원도         21,855   30,133   33,798   36,008   50,170   48,872   40,905
# 충청북도        25,067   35,178   38,112   38,091   50,784   57,942   48,632
# 충청남도        34,585   49,597   53,373   50,956   63,705   68,392   64,972
# 전라북도        23,900   38,177   43,131   45,344   58,331   54,138   43,637
# 전라남도        26,259   37,500   41,792   42,878   56,519   52,427   42,071
# 경상북도        37,539   55,271   57,455   59,272   78,791   78,376   70,213
# 경상남도        50,907   79,521   84,342   82,522  103,014  101,275   90,347
# 제주특별자치도     12,032   18,057   18,801   17,959   21,216   21,818   18,257
#
#             35~39세   40~44세   45~49세  ...   55~59세   60~64세   65~69세   70~74세  \
# 행정기관                                  ...
# 전국         1813973  2030616  2121949  ...  2079104  2043592  1445830   983284
# 서울특별시      355,012  362,766  373,556  ...  348,150  344,954  261,250  182,751
# 부산광역시      109,024  126,297  127,308  ...  131,999  144,693  113,836   79,759
# 대구광역시       76,617   87,878   96,400  ...   98,556   94,608   67,697   46,695
# 인천광역시      108,343  122,188  123,853  ...  124,406  119,238   76,768   48,655
# 광주광역시       49,779   56,629   60,816  ...   53,865   49,110   32,531   24,402
# 대전광역시       50,130   55,587   59,761  ...   55,131   54,153   37,725   24,818
# 울산광역시       40,831   47,638   46,442  ...   52,052   47,184   30,660   18,934
# 세종특별자치시     16,893   19,163   17,283  ...   10,633    9,773    6,674    4,161
# 경기도        517,312  577,824  588,745  ...  538,981  498,068  325,448  204,453
# 강원도         44,884   52,305   60,145  ...   67,065   74,118   54,734   32,025
# 충청북도        53,412   59,072   63,683  ...   67,640   70,453   50,028   30,967
# 충청남도        75,482   85,732   87,617  ...   85,616   87,216   62,377   46,189
# 전라북도        50,946   61,987   71,935  ...   74,798   75,965   56,213   44,632
# 전라남도        52,296   62,693   72,072  ...   83,456   83,642   59,683   49,351
# 경상북도        80,202   93,537  102,892  ...  117,338  122,505   92,325   65,759
# 경상남도       110,247  132,229  139,411  ...  141,537  143,064  100,955   67,772
# 제주특별자치도     22,563   27,091   30,030  ...   27,881   24,848   16,926   11,961
#
#             75~79세  80~84세  85~89세  90~94세 95~99세 100세 이상
# 행정기관
# 전국          696342  453472  192704   48788   9059    2099
# 서울특별시      134,277  82,383  32,570   8,683  1,799     580
# 부산광역시       54,377  32,542  11,904   2,783    460     134
# 대구광역시       31,004  20,338   8,655   1,833    300      64
# 인천광역시       33,310  20,081   8,496   2,251    455     118
# 광주광역시       17,460  10,801   4,303   1,135    176      31
# 대전광역시       17,221  10,824   4,692   1,190    203      37
# 울산광역시       10,893   5,883   2,198     470     75      11
# 세종특별자치시      2,684   1,710     846     229     37       9
# 경기도        147,598  95,165  40,736  10,736  2,162     523
# 강원도         27,804  19,539   7,563   2,033    512     106
# 충청북도        23,463  16,450   7,290   1,748    321      63
# 충청남도        32,665  23,768  12,529   3,039    519      90
# 전라북도        31,563  21,578  10,489   2,770    429      78
# 전라남도        35,625  25,821  10,741   2,852    508      63
# 경상북도        43,825  31,682  14,649   3,509    554      90
# 경상남도        43,680  29,016  12,390   2,962    464      89
# 제주특별자치도      8,893   5,891   2,653     565     85      13
#
# [18 rows x 21 columns]

# %% [markdown]
# ## 여자 데이터 정의

# %%
df_w = pd.read_excel(file_name, skiprows=3, index_col='행정기관', usecols='B, AB:AV')
df_w.head(3)
# Out:
# C:\Users\samta\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#           0~4세.1     5~9세.1   10~14세.1   15~19세.1   20~24세.1   25~29세.1  \
# 행정기관
# 전국       754,257  1,094,111  1,147,421  1,135,929  1,509,134  1,671,397
# 서울특별시    120,133    166,919    179,640    190,999    319,930    421,667
# 부산광역시     43,452     64,506     64,745     64,553     95,708    105,860
#
#           30~34세.1   35~39세.1   40~44세.1   45~49세.1  ...   55~59세.1  \
# 행정기관                                                 ...
# 전국       1,531,758  1,729,313  1,962,780  2,054,482  ...  2,019,778
# 서울특별시      367,071    355,208    369,195    380,583  ...    357,885
# 부산광역시       93,731    104,837    122,736    126,374  ...    139,888
#
#           60~64세.1   65~69세.1   70~74세.1 75~79세.1 80~84세.1 85~89세.1 90~94세.1  \
# 행정기관
# 전국       2,087,662  1,547,175  1,119,619  911,675  737,944  433,069  165,283
# 서울특별시      379,945    297,067    214,436  164,882  114,731   61,967   24,786
# 부산광역시      160,880    128,321     94,179   68,578   51,157   26,683    9,849
#
#         95~99세.1 100세 이상.1
# 행정기관
# 전국        38,111     8,190
# 서울특별시      6,162     1,648
# 부산광역시      2,105       547
#
# [3 rows x 21 columns]

# %%
df_w.columns = df_m.columns # 컬럼명 통일
df_w.columns
# Out:
# Index(['0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세',
#        '35~39세', '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세',
#        '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],
#       dtype='object')

# %%
df_w.iloc[0] = df_w.iloc[0].str.replace(',', '').astype(int) # 1,195,951 -> 1195951
df_w
# Out:
#               0~4세     5~9세   10~14세   15~19세   20~24세   25~29세   30~34세  \
# 행정기관
# 전국          754257  1094111  1147421  1135929  1509134  1671397  1531758
# 서울특별시      120,133  166,919  179,640  190,999  319,930  421,667  367,071
# 부산광역시       43,452   64,506   64,745   64,553   95,708  105,860   93,731
# 대구광역시       32,757   49,885   51,783   53,173   72,105   73,879   62,898
# 인천광역시       43,551   63,135   66,642   65,222   86,427  101,505   91,645
# 광주광역시       22,342   33,510   36,379   37,401   49,969   49,381   40,465
# 대전광역시       21,339   31,311   33,966   35,036   49,339   50,881   43,011
# 울산광역시       18,100   27,077   27,169   25,149   29,262   31,097   30,551
# 세종특별자치시      9,890   13,143   12,713    9,714    8,244   10,369   13,715
# 경기도        222,285  318,152  327,713  316,180  405,398  448,259  426,719
# 강원도         20,900   28,770   31,574   33,020   39,730   37,108   35,159
# 충청북도        23,752   33,906   35,741   34,814   42,948   43,553   40,640
# 충청남도        32,840   47,395   49,454   47,140   53,639   53,134   53,933
# 전라북도        22,933   35,954   40,627   41,705   50,058   45,310   39,663
# 전라남도        25,084   36,270   39,435   39,471   44,663   40,926   37,572
# 경상북도        35,601   51,890   53,163   52,459   61,389   58,853   57,683
# 경상남도        47,959   75,158   79,160   73,870   81,637   80,047   79,572
# 제주특별자치도     11,339   17,130   17,517   16,023   18,688   19,568   17,730
#
#             35~39세   40~44세   45~49세  ...   55~59세   60~64세   65~69세   70~74세  \
# 행정기관                                  ...
# 전국         1729313  1962780  2054482  ...  2019778  2087662  1547175  1119619
# 서울특별시      355,208  369,195  380,583  ...  357,885  379,945  297,067  214,436
# 부산광역시      104,837  122,736  126,374  ...  139,888  160,880  128,321   94,179
# 대구광역시       73,359   89,363   99,610  ...  102,108  101,349   77,316   56,896
# 인천광역시      102,081  115,436  118,889  ...  123,431  119,098   80,694   53,922
# 광주광역시       48,278   57,571   61,334  ...   54,502   52,945   36,575   29,775
# 대전광역시       47,480   55,936   60,227  ...   55,080   56,897   40,671   28,143
# 울산광역시       37,701   44,044   45,858  ...   47,931   45,922   30,883   19,314
# 세종특별자치시     17,699   19,533   15,931  ...    9,909    9,801    6,904    4,459
# 경기도        490,525  556,684  569,522  ...  516,018  491,723  340,103  231,134
# 강원도         41,914   50,725   56,240  ...   63,626   74,082   55,306   36,487
# 충청북도        48,679   54,810   59,431  ...   62,921   68,546   50,889   33,807
# 충청남도        66,249   74,856   77,080  ...   76,332   84,229   64,151   50,049
# 전라북도        48,959   59,244   67,284  ...   69,452   76,198   58,754   50,745
# 전라남도        47,505   56,125   61,741  ...   72,010   79,787   60,441   54,818
# 경상북도        73,129   85,607   95,012  ...  108,987  119,676   96,445   71,991
# 경상남도       103,109  124,344  131,657  ...  133,930  142,065  104,811   76,010
# 제주특별자치도     22,601   26,571   27,709  ...   25,768   24,519   17,844   13,454
#
#             75~79세   80~84세  85~89세  90~94세 95~99세 100세 이상
# 행정기관
# 전국          911675   737944  433069  165283  38111    8190
# 서울특별시      164,882  114,731  61,967  24,786  6,162   1,648
# 부산광역시       68,578   51,157  26,683   9,849  2,105     547
# 대구광역시       42,586   34,173  18,768   6,501  1,305     296
# 인천광역시       43,064   33,332  20,065   8,143  1,999     393
# 광주광역시       22,665   17,378   9,687   3,810    907     214
# 대전광역시       22,065   17,074  10,136   3,852    848     161
# 울산광역시       13,332    9,988   5,776   2,133    527      77
# 세종특별자치시      3,390    2,907   2,025     844    177      30
# 경기도        189,416  147,979  86,498  33,700  8,110   1,711
# 강원도         36,652   31,306  17,416   7,244  1,764     351
# 충청북도        31,616   27,621  17,275   6,108  1,323     255
# 충청남도        43,210   40,092  26,983   9,503  2,169     422
# 전라북도        44,064   37,986  24,603   9,473  1,947     417
# 전라남도        51,379   49,402  28,820  11,180  2,508     513
# 경상북도        61,800   57,798  36,027  13,063  2,891     558
# 경상남도        61,565   55,173  33,663  12,406  2,530     411
# 제주특별자치도     11,411    9,847   6,677   2,688    839     186
#
# [18 rows x 21 columns]

# %% [markdown]
# ## 데이터 시각화

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows
# matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
plt.figure(figsize=(10, 7))
plt.barh(df_m.columns, -df_m.iloc[0] / 1000) # 단위 : 천 명
plt.barh(df_w.columns, df_w.iloc[0] / 1000) # 단위 : 천 명
plt.title('2021년 대한민국 인구 피라미드')
plt.savefig('2021_인구피라미드.png', dpi=100)
